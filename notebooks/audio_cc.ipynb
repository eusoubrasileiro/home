# %% [markdown]
# ### Audio CC Latim, Matematica e Historia por semana do ano

# %%
import audiocc
import os

# %%
dfweeks = audiocc.dataframe_weeks()
dfweeks
# Out:
#        beg     end                audio1           audio2  \
# 1      NaN   34000  era_antigos_imperios             None
# 2    32000   52000  era_antigos_imperios             None
# 3    50000   78000  era_antigos_imperios             None
# 4    76000  101000  era_antigos_imperios             None
# 5    99000  129000  era_antigos_imperios             None
# 6   127000  154000  era_antigos_imperios             None
# 7   152000  185000  era_antigos_imperios             None
# 8   183000   28000  era_antigos_imperios      idade_media
# 9    26000   66000           idade_media             None
# 10   64000   96000           idade_media             None
# 11   94000  118000           idade_media             None
# 12  116000  148000           idade_media             None
# 13     NaN   47000          exploradores             None
# 14   45000   74000          exploradores             None
# 15   72000   11000          exploradores   era_iluminismo
# ...

# %%
audiocc.create_audios(dfweeks)
# Out:
# 100%|██████████| 24/24 [14:31<00:00, 36.31s/it]
